# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/home/placement/Downloads/fiat500.csv")

# %%
data.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1538.000000   1538.000000  1538.000000    1538.000000      1538.000000
# mean    769.500000     51.904421  1650.980494   53396.011704         1.123537
# std     444.126671      3.988023  1289.522278   40046.830723         0.416423
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     385.250000     51.000000   670.000000   20006.250000         1.000000
# 50%     769.500000     51.000000  1035.000000   39031.000000         1.000000
# 75%    1153.750000     51.000000  2616.000000   79667.750000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1538.000000  1538.000000   1538.000000
# mean     43.541361    11.563428   8576.003901
# std       2.133518     2.328190   1939.958641
# min      36.855839     7.245400   2500.000000
# 25%      41.802990     9.505090   7122.500000
# 50%      44.394096    11.869260   9000.000000
# 75%      45.467960    12.769040  10000.000000
# max      46.795612    18.365520  11100.000000

# %%
data.head()
# Out:
#    ID   model  engine_power  age_in_days      km  previous_owners        lat  \
# 0   1  lounge            51          882   25000                1  44.907242
# 1   2     pop            51         1186   32500                1  45.666359
# 2   3   sport            74         4658  142228                1  45.503300
# 3   4  lounge            51         2739  160000                1  40.633171
# 4   5     pop            73         3074  106880                1  41.903221
#
#          lon  price
# 0   8.611560   8900
# 1  12.241890   8800
# 2  11.417840   4200
# 3  17.634609   6000
# 4  12.495650   5700

# %%
#to remove a columns
data1=data.drop(['lat','lon','ID'],axis=1)
data1
# Out:
#        model  engine_power  age_in_days      km  previous_owners  price
# 0     lounge            51          882   25000                1   8900
# 1        pop            51         1186   32500                1   8800
# 2      sport            74         4658  142228                1   4200
# 3     lounge            51         2739  160000                1   6000
# 4        pop            73         3074  106880                1   5700
# ...      ...           ...          ...     ...              ...    ...
# 1533   sport            51         3712  115280                1   5200
# 1534  lounge            74         3835  112000                1   4600
# 1535     pop            51         2223   60457                1   7500
# 1536  lounge            51         2557   80750                1   5990
# 1537     pop            51         1766   54276                1   7900
#
# [1538 rows x 6 columns]

# %%
data3=data.loc[(data.model=='lounge')]
data3
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 3        4  lounge            51         2739  160000                1
# 6        7  lounge            51          731   11600                1
# 7        8  lounge            51         1521   49076                1
# 11      12  lounge            51          366   17500                1
# ...    ...     ...           ...          ...     ...              ...
# 1528  1529  lounge            51         2861  126000                1
# 1529  1530  lounge            51          731   22551                1
# 1530  1531  lounge            51          670   29000                1
# 1534  1535  lounge            74         3835  112000                1
# 1536  1537  lounge            51         2557   80750                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 3     40.633171  17.634609   6000
# 6     44.907242   8.611560  10750
# 7     41.903221  12.495650   9190
# 11    45.069679   7.704920  10990
# ...         ...        ...    ...
# 1528  43.841980  10.515310   5500
# 1529  38.122070  13.361120   9900
# 1530  45.764648   8.994500  10800
# 1534  45.845692   8.666870   4600
# 1536  45.000702   7.682270   5990
#
# [1094 rows x 9 columns]

# %%
data=pd.get_dummies(data)
data
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 1        2            51         1186   32500                1  45.666359
# 2        3            74         4658  142228                1  45.503300
# 3        4            51         2739  160000                1  40.633171
# 4        5            73         3074  106880                1  41.903221
# ...    ...           ...          ...     ...              ...        ...
# 1533  1534            51         3712  115280                1  45.069679
# 1534  1535            74         3835  112000                1  45.845692
# 1535  1536            51         2223   60457                1  45.481541
# 1536  1537            51         2557   80750                1  45.000702
# 1537  1538            51         1766   54276                1  40.323410
#
#             lon  price  model_lounge  model_pop  model_sport
# 0      8.611560   8900             1          0            0
# 1     12.241890   8800             0          1            0
# 2     11.417840   4200             0          0            1
# 3     17.634609   6000             1          0            0
# 4     12.495650   5700             0          1            0
# ...         ...    ...           ...        ...          ...
# 1533   7.704920   5200             0          0            1
# 1534   8.666870   4600             1          0            0
# 1535   9.413480   7500             0          1            0
# 1536   7.682270   5990             1          0            0
# 1537  17.568270   7900             0          1            0
#
# [1538 rows x 11 columns]

# %%
data.shape
# Out:
# (1538, 11)

# %%
data2=pd.get_dummies(data3)

# %%
data2
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 0        1            51          882   25000                1  44.907242
# 3        4            51         2739  160000                1  40.633171
# 6        7            51          731   11600                1  44.907242
# 7        8            51         1521   49076                1  41.903221
# 11      12            51          366   17500                1  45.069679
# ...    ...           ...          ...     ...              ...        ...
# 1528  1529            51         2861  126000                1  43.841980
# 1529  1530            51          731   22551                1  38.122070
# 1530  1531            51          670   29000                1  45.764648
# 1534  1535            74         3835  112000                1  45.845692
# 1536  1537            51         2557   80750                1  45.000702
#
#             lon  price  model_lounge
# 0      8.611560   8900             1
# 3     17.634609   6000             1
# 6      8.611560  10750             1
# 7     12.495650   9190             1
# 11     7.704920  10990             1
# ...         ...    ...           ...
# 1528  10.515310   5500             1
# 1529  13.361120   9900             1
# 1530   8.994500  10800             1
# 1534   8.666870   4600             1
# 1536   7.682270   5990             1
#
# [1094 rows x 9 columns]

# %%
data2.shape
# Out:
# (1094, 9)

# %%
y=data2['price']
x=data2.drop('price',axis=1)

# %%
y
# Out:
# 0        8900
# 3        6000
# 6       10750
# 7        9190
# 11      10990
#         ...
# 1528     5500
# 1529     9900
# 1530    10800
# 1534     4600
# 1536     5990
# Name: price, Length: 1094, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =train_test_split(x,y, test_size=0.33,random_state=42)

# %%
x_test.head(5)
# Out:
#         ID  engine_power  age_in_days      km  previous_owners        lat  \
# 676    677            51          762   18609                1  41.572239
# 215    216            51          701   25000                1  44.988739
# 146    147            51         4018  152900                1  43.067532
# 1319  1320            51          731   20025                1  41.689281
# 1041  1042            51          640   38231                1  41.107880
#
#            lon  model_lounge
# 676   13.33369             1
# 215    9.01050             1
# 146   12.55155             1
# 1319  13.25494             1
# 1041  14.20881             1

# %%
x_train.shape
# Out:
# (732, 8)

# %%
y_train
# Out:
# 441      8980
# 701     10300
# 695      5880
# 1415    10490
# 404      9499
#         ...
# 459     10850
# 654      5900
# 189     10000
# 1455     9400
# 1218     8900
# Name: price, Length: 732, dtype: int64

# %%
y_test.head()
# Out:
# 676     10250
# 215      9790
# 146      5500
# 1319     9900
# 1041     8900
# Name: price, dtype: int64

# %%
y_train.shape
# Out:
# (732,)

# %%
#!pip3 install scikit-learn

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
alpha=[1e-15,1e-10,1e-8,1e-4,1e-3,1e-2,1,5,10,20,30]
ridge=Ridge()
parameters={'alpha':alpha}
ridge_regressor=GridSearchCV(ridge,parameters)
ridge_regressor.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_regressor.best_params_
# Out:
# {'alpha': 30}

# %%
ridge=Ridge(alpha=30)
ridge.fit(x_train,y_train)
y_pred_ridge=ridge.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
Ridge_Error=mean_squared_error(y_pred_ridge,y_test)
Ridge_Error
# Out:
# 529111.0455362241

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred_ridge)
# Out:
# 0.8343797517106646

# %%
import seaborn as sns
Results=pd.DataFrame(columns=['Actual','Predicted'])
Results['Actual']=y_test
Results['Predicted']=y_pred_ridge
Results=Results.reset_index()
Results['ID']=Results.index
Results.head(10)
# Out:
#    index  Actual     Predicted  ID
# 0    676   10250   9912.601754   0
# 1    215    9790  10141.748493   1
# 2    146    5500   4775.235521   2
# 3   1319    9900   9870.926966   3
# 4   1041    8900   9630.417885   4
# 5   1425    9500   8697.092014   5
# 6    409   10450  10265.822884   6
# 7    617    9790  10293.851867   7
# 8   1526    9300   8614.349738   8
# 9   1010    4600   5749.673567   9

# %%
import matplotlib.pyplot as plt
sns.lineplot(x='ID',y='Actual',data=Results.head(50))
sns.lineplot(x='ID',y='Predicted',data=Results.head(50))
plt.plot()
# Out:
# []
